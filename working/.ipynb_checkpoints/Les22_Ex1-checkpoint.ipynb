# %% [markdown]
# ## Lesson 22:
# ### Exercise 1: Galaxies vs Quasars with neural networks

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
# %config InlineBackend.figure_format='retina'

c = sns.color_palette('Paired', 7)
plt.rcParams['figure.figsize'] = (8, 5)

#------------------- Function to read the data -------------------
def Dataframe(namefile):                                        #-
    df = pd.read_csv(namefile, sep=',', skipinitialspace=True)  #-
    return df                                                   #-
#-----------------------------------------------------------------

if "setup_text_plots" not in globals():
    from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=10, usetex=False)
# Out:
# /home/nicolofiaba/.local/lib/python3.10/site-packages/astroML/linear_model/linear_regression_errors.py:10: UserWarning: LinearRegressionwithErrors requires PyMC3 to be installed
#   warnings.warn('LinearRegressionwithErrors requires PyMC3 to be installed')

# %%
data = Dataframe("galaxyquasar.csv")
data = data.dropna()
num_rows = len(data.index)

# %%
u_g = np.array(data['u'] - data['g'])
g_r = np.array(data['g'] - data['r'])
r_i = np.array(data['r'] - data['i'])
i_z = np.array(data['i'] - data['z'])
classes = np.where(data['class']=='QSO', 1, 0) # 1 is QSO, 0 is GALAXY

# add those as dataframe columns
data['u-g'] = u_g
data['g-r'] = g_r
data['r-i'] = r_i
data['i-z'] = i_z
data['class_num'] = classes

X = data.loc[:, ['u-g', 'g-r', 'r-i', 'i-z']].to_numpy()
y = data.loc[:, ['class_num']].to_numpy()

# %% [markdown]
# ### Data normalization + training/test split
# We can split the entire dataset into a **training set** and a **test set** using the Scikit Learn *train_test_split* function. $30\%$ of the data goes into the test set. But first we normalize our dataset so that it has zero mean and unit variance in every dimension. This can also be done using te usual *StandardScaler* module of *Scikit-learn*

# %%
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.layers import Normalization
# Out:
# 2024-06-20 00:47:30.963393: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-20 00:47:30.964940: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-20 00:47:30.994136: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-20 00:47:30.994725: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-20 00:47:31.768755: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
normalizer = Normalization(axis=-1)
normalizer.adapt(X)
X_scaled = np.array(normalizer(X))
print(X_scaled)
# Out:
# [[-1.6009315  -2.1856418  -0.5065469  -0.6597548 ]
#  [ 0.8389082   1.1876656   0.41731626  0.47661254]
#  [ 0.7716434   0.50527114 -0.04953469 -0.14751536]
#  ...
#  [ 0.01402752 -0.6316651  -0.43134817 -0.1131583 ]
#  [-0.06667943  0.08235198  0.26992127 -0.17028071]
#  [-0.47648627 -0.89827895 -0.71412855 -0.5216425 ]]

# %%
# 30% test set, 70% training set
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3, random_state=42)
print('Training dataset: ')
print(X_train)
print('\nShape of train:')
print(X_train.shape)
print('\nTest dataset: \n')
print(X_test)
print('\nShape of test:')
print(X_test.shape)
# Out:
# Training dataset:
# [[-0.25857967 -0.42241818 -0.07498585 -0.15694074]
#  [ 0.04050914  0.7225612   0.5851738   0.2751449 ]
#  [-0.45488775  0.2466035   0.3954218  -0.12733439]
#  ...
#  [-0.11176035 -0.532759   -0.39111596 -0.15777688]
#  [ 0.2232835   0.04969563 -0.26626214 -0.2842215 ]
#  [-2.1775286  -1.6597466  -0.00537629 -0.62349755]]
#
# Shape of train:
# (35000, 4)
#
# Test dataset:
#
# [[-0.25038645  0.45543054  0.17860198  0.25781438]
#  [ 0.4563877   0.10218507  0.18474531  0.20890112]
#  [-1.8718194  -1.3098927  -0.75154316 -0.8665433 ]
#  ...
#  [ 1.0172385   0.6242687   0.23158284  0.33386356]
#  [ 1.0394042   0.80974203  0.40521422  0.42728132]
#  [ 0.85955596  0.77159435  0.6788487   0.54962134]]
#
# Shape of test:
# (15000, 4)

# %%
def pred_visualization(X_test, y_test, y_p):
    fig = plt.figure()
    
    galaxies = (y_p == 0)

    plt.scatter(X_test[galaxies][:, 0], X_test[galaxies][:, 1], 
            s=10, edgecolors='none', alpha=0.5, 
            label='Galaxy', color=c[3])

    plt.scatter(X_test[~galaxies][:, 0], X_test[~galaxies][:, 1], 
            s=10, edgecolors='none', alpha=0.5, 
            label='QSO', color=c[6])
    
    plt.xlim(-4, 3)
    plt.ylim(-5, 5)
    plt.xlabel('u-g')
    plt.ylabel('g-r')
    plt.legend(loc='best', fontsize=10, frameon=True)
    plt.grid(True, ls='--', alpha=0.2)

# %%
tf.random.set_seed(42)

# Create the network
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=X_train.shape[1]),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.001
#----------------------------------------------------------------------------
""" Adapting learning rate: not producing better accuracies.

initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.96, staircase=True)
"""
#----------------------------------------------------------------------------
# Compile
model.compile(loss=tf.keras.losses.binary_crossentropy,
             optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate),
             metrics=['accuracy'])
# Fit
history = model.fit(X_train, y_train,
                   epochs=25)
# Out:
# Epoch 1/25
# 1094/1094 [==============================] - 1s 633us/step - loss: 0.0857 - accuracy: 0.9819
# Epoch 2/25
# 1094/1094 [==============================] - 1s 634us/step - loss: 0.0614 - accuracy: 0.9845
# Epoch 3/25
# 1094/1094 [==============================] - 1s 650us/step - loss: 0.0559 - accuracy: 0.9845
# Epoch 4/25
# 1094/1094 [==============================] - 1s 694us/step - loss: 0.0556 - accuracy: 0.9849
# Epoch 5/25
# 1094/1094 [==============================] - 1s 676us/step - loss: 0.0556 - accuracy: 0.9849
# Epoch 6/25
# 1094/1094 [==============================] - 1s 626us/step - loss: 0.0556 - accuracy: 0.9851
# Epoch 7/25
# 1094/1094 [==============================] - 1s 660us/step - loss: 0.0548 - accuracy: 0.9857
# Epoch 8/25
# 1094/1094 [==============================] - 1s 636us/step - loss: 0.0556 - accuracy: 0.9860
# Epoch 9/25
# 1094/1094 [==============================] - 1s 626us/step - loss: 0.0554 - accuracy: 0.9859
# Epoch 10/25
# 1094/1094 [==============================] - 1s 632us/step - loss: 0.0567 - accuracy: 0.9861
# Epoch 11/25
# 1094/1094 [==============================] - 1s 636us/step - loss: 0.0565 - accuracy: 0.9857
# Epoch 12/25
# 1094/1094 [==============================] - 1s 671us/step - loss: 0.0575 - accuracy: 0.9862
# Epoch 13/25
# 1094/1094 [==============================] - 1s 639us/step - loss: 0.0579 - accuracy: 0.9863
# Epoch 14/25
# 1094/1094 [==============================] - 1s 648us/step - loss: 0.0562 - accuracy: 0.9861
# Epoch 15/25
# 1094/1094 [==============================] - 1s 661us/step - loss: 0.0573 - accuracy: 0.9863
# Epoch 16/25
# 1094/1094 [==============================] - 1s 668us/step - loss: 0.0558 - accuracy: 0.9863
# Epoch 17/25
# 1094/1094 [==============================] - 1s 666us/step - loss: 0.0588 - accuracy: 0.9863
# Epoch 18/25
# 1094/1094 [==============================] - 1s 654us/step - loss: 0.0565 - accuracy: 0.9867
# Epoch 19/25
# 1094/1094 [==============================] - 1s 674us/step - loss: 0.0571 - accuracy: 0.9862
# Epoch 20/25
# 1094/1094 [==============================] - 1s 671us/step - loss: 0.0563 - accuracy: 0.9863
# Epoch 21/25
# 1094/1094 [==============================] - 1s 696us/step - loss: 0.0560 - accuracy: 0.9863
# Epoch 22/25
# 1094/1094 [==============================] - 1s 661us/step - loss: 0.0566 - accuracy: 0.9864
# Epoch 23/25
# 1094/1094 [==============================] - 1s 696us/step - loss: 0.0577 - accuracy: 0.9866
# Epoch 24/25
# 1094/1094 [==============================] - 1s 691us/step - loss: 0.0596 - accuracy: 0.9866
# Epoch 25/25
# 1094/1094 [==============================] - 1s 693us/step - loss: 0.0574 - accuracy: 0.9863

# %%
y_pred = model.predict(X_test)

# We approximate every value below 0.5 to 0 and above 0.5 to 1
y_pred_binary = np.array(tf.round(y_pred)).ravel()
# Out:
# 469/469 [==============================] - 0s 393us/step

# %%
pred_visualization(X_test, y_test, y_pred_binary)

# %% [markdown]
# Now we evaluate the model on the test set

# %%
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 469/469 [==============================] - 0s 464us/step - loss: 0.0615 - accuracy: 0.9854

# %%
print('The accuracy of our Neural Network Classifier is', round(accuracy*100, 2), '%')
# Out:
# The accuracy of our Neural Network Classifier is 98.54 %

# %%
from sklearn.metrics import roc_curve, auc

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
ax.plot([0,1], [0,1], '--k', label='random guess')

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc_tf = auc(fpr, tpr)

ax.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_tf), color=c[3])
ax.fill_between(fpr, tpr, color=c[3], alpha=0.1)
ax.set_xlabel('fpr');
ax.set_ylabel('tpr');
ax.legend(loc='lower right', frameon=False);
ax.grid(True, ls='--', alpha=0.2)

plt.show()

# %% [markdown]
# ---
# #### Let's try some PCA dimensionality reduction before performing classification...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2) 
pca.fit(X_scaled)

proj = pca.transform(X_scaled) # projection of the data: This reconstructs the signal using the two components ICA computed
# comp = ica.components_

# %%
pca_xtrain, pca_xtest, pca_ytrain, pca_ytest = train_test_split(proj, y, test_size = 0.3, random_state=42)

# %%
tf.random.set_seed(42)

# Create the network
model_pca = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=pca_xtrain.shape[1]),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.001
#----------------------------------------------------------------------------
""" Adapting learning rate: not producing better accuracies.

initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.96, staircase=True)
"""
#----------------------------------------------------------------------------
# Compile
model_pca.compile(loss=tf.keras.losses.binary_crossentropy,
             optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate),
             metrics=['accuracy'])
# Fit
history = model_pca.fit(pca_xtrain, pca_ytrain,
                   epochs=25)
# Out:
# Epoch 1/25
# 1094/1094 [==============================] - 1s 644us/step - loss: 0.1208 - accuracy: 0.9672
# Epoch 2/25
# 1094/1094 [==============================] - 1s 644us/step - loss: 0.0996 - accuracy: 0.9712
# Epoch 3/25
# 1094/1094 [==============================] - 1s 637us/step - loss: 0.0973 - accuracy: 0.9715
# Epoch 4/25
# 1094/1094 [==============================] - 1s 634us/step - loss: 0.0971 - accuracy: 0.9710
# Epoch 5/25
# 1094/1094 [==============================] - 1s 702us/step - loss: 0.0957 - accuracy: 0.9719
# Epoch 6/25
# 1094/1094 [==============================] - 1s 635us/step - loss: 0.0961 - accuracy: 0.9717
# Epoch 7/25
# 1094/1094 [==============================] - 1s 642us/step - loss: 0.0949 - accuracy: 0.9718
# Epoch 8/25
# 1094/1094 [==============================] - 1s 636us/step - loss: 0.0965 - accuracy: 0.9725
# Epoch 9/25
# 1094/1094 [==============================] - 1s 636us/step - loss: 0.0949 - accuracy: 0.9722
# Epoch 10/25
# 1094/1094 [==============================] - 1s 645us/step - loss: 0.0957 - accuracy: 0.9725
# Epoch 11/25
# 1094/1094 [==============================] - 1s 646us/step - loss: 0.0955 - accuracy: 0.9723
# Epoch 12/25
# 1094/1094 [==============================] - 1s 655us/step - loss: 0.0959 - accuracy: 0.9724
# Epoch 13/25
# 1094/1094 [==============================] - 1s 643us/step - loss: 0.0980 - accuracy: 0.9725
# Epoch 14/25
# 1094/1094 [==============================] - 1s 655us/step - loss: 0.0955 - accuracy: 0.9723
# Epoch 15/25
# 1094/1094 [==============================] - 1s 657us/step - loss: 0.0971 - accuracy: 0.9723
# Epoch 16/25
# 1094/1094 [==============================] - 1s 663us/step - loss: 0.0954 - accuracy: 0.9724
# Epoch 17/25
# 1094/1094 [==============================] - 1s 666us/step - loss: 0.0973 - accuracy: 0.9727
# Epoch 18/25
# 1094/1094 [==============================] - 1s 663us/step - loss: 0.0959 - accuracy: 0.9727
# Epoch 19/25
# 1094/1094 [==============================] - 1s 665us/step - loss: 0.0966 - accuracy: 0.9728
# Epoch 20/25
# 1094/1094 [==============================] - 1s 666us/step - loss: 0.0950 - accuracy: 0.9725
# Epoch 21/25
# 1094/1094 [==============================] - 1s 671us/step - loss: 0.0964 - accuracy: 0.9725
# Epoch 22/25
# 1094/1094 [==============================] - 1s 667us/step - loss: 0.0965 - accuracy: 0.9728
# Epoch 23/25
# 1094/1094 [==============================] - 1s 639us/step - loss: 0.0965 - accuracy: 0.9728
# Epoch 24/25
# 1094/1094 [==============================] - 1s 676us/step - loss: 0.0969 - accuracy: 0.9725
# Epoch 25/25
# 1094/1094 [==============================] - 1s 658us/step - loss: 0.0967 - accuracy: 0.9724

# %%
pca_y_pred = model_pca.predict(pca_xtest)

# We approximate every value below 0.5 to 0 and above 0.5 to 1
pca_y_pred_binary = np.array(tf.round(pca_y_pred)).ravel()
# Out:
# 469/469 [==============================] - 0s 368us/step

# %%
loss_pca, accuracy_pca = model_pca.evaluate(pca_xtest, pca_ytest)
# Out:
# 469/469 [==============================] - 0s 476us/step - loss: 0.0921 - accuracy: 0.9736

# %%
print('The accuracy of the Neural Network Classifier, with PCA applied first, is', round(accuracy_pca*100, 2), '%')
# Out:
# The accuracy of the Neural Network Classifier, with PCA applied first, is 97.36 %

# %% [markdown]
# The accuracy was **not** improved by applying PCA first.

# %% [markdown]
# ---
#
# #### Final comments:
#
# We played with the neural network hyperparameters (varying the number of hidden layers, neurons in each layer,, adding dropout layers, changing the optimizer), but in the end, the best classification accuracy ($98.54\%$) was obtained with the architecture shown above:
#
# - 3 hidden layers with 64, 128 and 64 neurons respectively and a `REctified Linear Unit` activation function.
# - Output layer with 1 neuron and a `Sigmoid` activation function
# - Initial learning rate equal to $0.001$
# - `RMSProp` optimizer
# - 25 epochs
# - `binary_crossentropy` loss function (standard for classification problems)
# - No dimensionality reduction before classification
